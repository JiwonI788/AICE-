# %% [markdown]
# ## 1. 머신러닝 개요
#
# 이번 주에는 머신러닝의 기본 개념을 학습하고, 간단한 데이터를 불러와 전처리하는 방법을 실습했습니다.
#
# ## 💡 머신러닝이란?
# - 데이터를 기반으로 패턴을 학습하고 예측하는 알고리즘
# - **지도학습**, **비지도학습**, **강화학습**으로 구분됨

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris

# 데이터 불러오기
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['target'] = iris.target
df.head()#데이터 확인. 앞의 5줄만 보여줌.
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# <details>
# <summary>iris 의 데이터 정보확인</summary>
#
# `load_iris()`는 scikit-learn에서 제공하는 데이터셋.
# `.data`, `.target`, `.feature_names` 등으로 정보에 접근가능.
#
# ```python
# #데이터 정보 확인
# iris = load_iris()
# print(type(iris))
# print(len(iris))
# print(iris)
# ``` </details>

# %%
# 결측치 확인 : 머신러닝에서 데이터에 null이 있으면 실행에 오류가 나기때문에 꼭 확인을 해줘야함!
df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
# seaborn 을 이용한 시각화
import matplotlib.pyplot as plt
import seaborn as sns#1.데이터 시각화를 쉽게 해주는 라이브러리. 2.통계 그래프에 적합. 3.matplotlib 보다 예쁘고 간단하게 그릴 수 있음.

sns.pairplot(df, hue='target')
plt.title("Iris 데이터 시각화")
plt.show()
# Out:
# /Users/jiwonju/anaconda3/envs/qml1w/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 45936 (\N{HANGUL SYLLABLE DE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/jiwonju/anaconda3/envs/qml1w/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/jiwonju/anaconda3/envs/qml1w/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 53552 (\N{HANGUL SYLLABLE TEO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/jiwonju/anaconda3/envs/qml1w/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/jiwonju/anaconda3/envs/qml1w/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/jiwonju/anaconda3/envs/qml1w/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## ✍️ 배운 점
#
# - Scikit-learn에서 기본 제공하는 데이터셋 로딩법을 익힘
# - Pandas를 활용한 데이터 전처리, Seaborn을 이용한 시각화 기법을 실습함
# - 머신러닝은 통계적 직관과 함께 데이터를 바라보는 관점이 중요하다는 것을 느낌
#
# ## 📌 다음 주 목표
#
# - 선형 회귀 모델을 수식과 코드 양쪽으로 이해하기
# - MSE, R^2 등의 평가 지표 직접 계산해보기
